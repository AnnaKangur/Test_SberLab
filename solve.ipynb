# %%
# tracker
import math

class Tracker:
    def __init__(self):
        self.center_points = {} # Store the center positions of the objects
        self.id_count = 0 # Keep the count of the IDs each time a new object id detected, the count will increase by one


    def update(self, objects_rect):
        # Objects boxes and ids
        objects_bbs_ids = []

        # Get center point of new object
        for rect in objects_rect:
            x, y, w, h = rect
            cx = (x + x + w) // 2
            cy = (y + y + h) // 2

            # Find out if that object was detected already
            same_object_detected = False
            for id, pt in self.center_points.items():
                
                dist = math.hypot(cx - pt[0], cy - pt[1])

                if dist < 35:
                    self.center_points[id] = (cx, cy)
                    # print(self.center_points)
                    objects_bbs_ids.append([x, y, w, h, id])
                    same_object_detected = True
                    break

            # New object is detected we assign the ID to that object
            if same_object_detected is False:
                self.center_points[self.id_count] = (cx, cy)
                objects_bbs_ids.append([x, y, w, h, self.id_count])
                self.id_count += 1

        # Clean the dictionary by center points to remove IDS not used anymore
        new_center_points = {}
        for obj_bb_id in objects_bbs_ids:
            _, _, _, _, object_id = obj_bb_id
            center = self.center_points[object_id]
            new_center_points[object_id] = center

        # Update dictionary with IDs not used removed
        self.center_points = new_center_points.copy()
        return objects_bbs_ids

# %%
import cv2
import pandas as pd
import numpy as np
from ultralytics import YOLO
# from tracker import *

# %%
model=YOLO('yolov8s.pt')

# %%
cap = cv2.VideoCapture('traffic.mp4')
assert cap.isOpened(), "Error reading video file"

# %%
my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")
print(class_list)
# Out:
# ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
cap = cv2.VideoCapture('traffic.mp4')
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
w, h, fps
# Out:
# (1280, 720, 30)

# %%
count=0
tracker=Tracker() 

# Define line points
x1 = 150
x2 = 1000
y1 = 650
y2 = 700
area = [(x1, y1), (x2, y1), (x2, y2), (x1, y2)]
area_c = set()

# %%
# Video writer
video_writer = cv2.VideoWriter("output.avi", 
                               cv2.VideoWriter_fourcc(*'mp4v'), 
                               fps, 
                               (w, h))
             
while True:    
    ret, frame = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    
    results = model.predict(frame)
    
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")
    
    list = []
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        list.append([x1, y1, x2, y2])
            
    bbox_idx = tracker.update(list)
    # print('bbox_idx = ', bbox_idx)
    
    for bbox in bbox_idx:
        x3, y3, x4, y4, id = bbox
        cx = int(x3 + x4) // 2
        cy = int(y3 + y4) // 2
        
        # Функция cv2.pointPolygonTest() в OpenCV находит наименьшее расстояние между точкой на изображении и контуром.
        # Она возвращает расстояние, которое:
        #     является отрицательным, если точка находится за контуром;
        #     является положительным, если точка находится внутри контура;
        #     равно нулю, если точка находится на контуре.
        results = cv2.pointPolygonTest(np.array(area, np.int32), ((x4, y4)), False)
        # print(results)
        
        if results >= 0:
            # рисование простого, объёмного или заполненного вертикального прямоугольника.
            cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
            # наложения текста на изображение.
            cv2.putText(frame, str("car"), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0), 1) # str(int(id))
            area_c.add(id)

        
    area1_c = (len(area_c))
    cv2.putText(frame, str(int(area1_c)), (1000, 60), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0, 0), 2)
    cv2.polylines(frame, [np.array(area, np.int32)], True, (255, 0, 0), 2)
    
    # print(frame.shape)
    im0 = frame
    video_writer.write(im0)
    
    # print('break')
    # break
        
cap.release()
# cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 cars, 1 truck, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 56.1ms
# Speed: 1.7ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 52.2ms
# Speed: 1.7ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 50.0ms
# Speed: 1.9ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 55.4ms
# Speed: 1.8ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 56.5ms
# Speed: 1.6ms preprocess, 56.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 52.7ms
# Speed: 1.7ms preprocess, 52.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 51.8ms
# Speed: 2.1ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 52.3ms
# Speed: 1.7ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 52.4ms
# Speed: 1.6ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 52.7ms
# Speed: 1.5ms preprocess, 52.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 51.9ms
# Speed: 1.9ms preprocess, 51.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 50.8ms
# Speed: 1.8ms preprocess, 50.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 50.9ms
# Speed: 1.8ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 52.1ms
# Speed: 1.7ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 41.3ms
# Speed: 1.7ms preprocess, 41.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.0ms
# Speed: 1.8ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 42.0ms
# Speed: 1.9ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.4ms
# Speed: 2.0ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.2ms
# Speed: 1.9ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 44.8ms
# Speed: 1.7ms preprocess, 44.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.0ms
# Speed: 1.6ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 42.0ms
# Speed: 1.9ms preprocess, 42.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.0ms
# Speed: 2.0ms preprocess, 41.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 41.5ms
# Speed: 1.9ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 41.6ms
# Speed: 1.9ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 44.4ms
# Speed: 1.9ms preprocess, 44.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.2ms
# Speed: 1.9ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.3ms
# Speed: 1.9ms preprocess, 41.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.7ms
# Speed: 2.1ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.5ms
# Speed: 1.9ms preprocess, 41.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.8ms
# Speed: 1.9ms preprocess, 40.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 40.4ms
# Speed: 1.9ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 42.6ms
# Speed: 2.2ms preprocess, 42.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 45.9ms
# Speed: 1.9ms preprocess, 45.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 52.5ms
# Speed: 1.9ms preprocess, 52.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 53.6ms
# Speed: 1.9ms preprocess, 53.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 54.3ms
# Speed: 1.9ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 52.4ms
# Speed: 1.8ms preprocess, 52.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 52.6ms
# Speed: 1.9ms preprocess, 52.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 53.4ms
# Speed: 1.7ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 47.6ms
# Speed: 1.8ms preprocess, 47.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 44.2ms
# Speed: 1.8ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.8ms
# Speed: 2.0ms preprocess, 41.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 43.8ms
# Speed: 1.8ms preprocess, 43.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.5ms
# Speed: 1.9ms preprocess, 40.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 45.7ms
# Speed: 1.9ms preprocess, 45.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 47.3ms
# Speed: 1.9ms preprocess, 47.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 44.7ms
# Speed: 1.7ms preprocess, 44.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 45.6ms
# Speed: 2.5ms preprocess, 45.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 43.3ms
# Speed: 2.0ms preprocess, 43.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 52.2ms
# Speed: 1.9ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 41.3ms
# Speed: 1.7ms preprocess, 41.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 41.9ms
# Speed: 1.9ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 43.3ms
# Speed: 1.9ms preprocess, 43.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 101.2ms
# Speed: 1.7ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 72.0ms
# Speed: 1.8ms preprocess, 72.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 39.2ms
# Speed: 1.7ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 40.0ms
# Speed: 1.8ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 39.1ms
# Speed: 1.7ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 motorcycle, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 39.1ms
# Speed: 1.8ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 42.0ms
# Speed: 1.8ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 40.7ms
# Speed: 1.9ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 46.0ms
# Speed: 1.6ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 40.0ms
# Speed: 1.8ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 motorcycle, 58.5ms
# Speed: 1.8ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 2 motorcycles, 1 truck, 42.2ms
# Speed: 1.9ms preprocess, 42.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 2 motorcycles, 1 truck, 40.4ms
# Speed: 2.0ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 2 motorcycles, 1 truck, 44.7ms
# Speed: 2.0ms preprocess, 44.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 motorcycles, 1 truck, 52.5ms
# Speed: 1.7ms preprocess, 52.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 bus, 42.9ms
# Speed: 1.7ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 1 bus, 42.2ms
# Speed: 1.8ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 motorcycles, 1 bus, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 motorcycles, 1 bus, 42.6ms
# Speed: 2.1ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 motorcycles, 1 bus, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 motorcycles, 1 bus, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 40.0ms
# Speed: 2.1ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 motorcycle, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 44.0ms
# Speed: 1.8ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 39.9ms
# Speed: 1.9ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 58.8ms
# Speed: 1.9ms preprocess, 58.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 39.6ms
# Speed: 1.7ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 40.9ms
# Speed: 1.9ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 46.5ms
# Speed: 1.9ms preprocess, 46.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.0ms
# Speed: 2.1ms preprocess, 41.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.6ms
# Speed: 1.9ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 42.4ms
# Speed: 2.0ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 42.3ms
# Speed: 1.9ms preprocess, 42.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 44.9ms
# Speed: 1.8ms preprocess, 44.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 43.4ms
# Speed: 1.8ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 40.9ms
# Speed: 1.9ms preprocess, 40.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 44.5ms
# Speed: 1.8ms preprocess, 44.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 40.9ms
# Speed: 1.9ms preprocess, 40.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 42.5ms
# Speed: 1.9ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 41.3ms
# Speed: 1.9ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 175.6ms
# Speed: 3.1ms preprocess, 175.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.7ms
# Speed: 2.1ms preprocess, 41.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.3ms
# Speed: 1.8ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 40.8ms
# Speed: 1.9ms preprocess, 40.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.2ms
# Speed: 1.8ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 42.8ms
# Speed: 1.9ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.4ms
# Speed: 1.6ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 42.0ms
# Speed: 2.1ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.0ms
# Speed: 1.8ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 43.2ms
# Speed: 1.8ms preprocess, 43.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 44.9ms
# Speed: 1.6ms preprocess, 44.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.8ms
# Speed: 1.9ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.8ms
# Speed: 1.9ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 39.9ms
# Speed: 2.0ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 45.6ms
# Speed: 1.8ms preprocess, 45.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 42.0ms
# Speed: 1.9ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.2ms
# Speed: 1.8ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.9ms
# Speed: 1.9ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 51.3ms
# Speed: 1.7ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.3ms
# Speed: 1.8ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.7ms
# Speed: 2.2ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 66.4ms
# Speed: 1.8ms preprocess, 66.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 38.9ms
# Speed: 2.7ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 39.7ms
# Speed: 1.7ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 39.9ms
# Speed: 1.7ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 43.2ms
# Speed: 1.8ms preprocess, 43.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 41.5ms
# Speed: 1.8ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 41.3ms
# Speed: 1.9ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.0ms
# Speed: 1.9ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 41.5ms
# Speed: 1.7ms preprocess, 41.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 40.9ms
# Speed: 1.9ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 43.1ms
# Speed: 1.9ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 43.2ms
# Speed: 1.8ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 trucks, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 40.4ms
# Speed: 2.5ms preprocess, 40.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 39.1ms
# Speed: 1.7ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 53.6ms
# Speed: 1.7ms preprocess, 53.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 52.3ms
# Speed: 1.8ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 51.7ms
# Speed: 1.7ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 53.7ms
# Speed: 1.9ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 44.8ms
# Speed: 1.9ms preprocess, 44.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 2 trucks, 42.9ms
# Speed: 1.9ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 2 trucks, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 truck, 41.8ms
# Speed: 1.9ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 63.7ms
# Speed: 1.8ms preprocess, 63.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 truck, 64.9ms
# Speed: 1.9ms preprocess, 64.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 truck, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 42.1ms
# Speed: 1.8ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 41.5ms
# Speed: 1.7ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 41.1ms
# Speed: 1.9ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 42.9ms
# Speed: 2.0ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 45.4ms
# Speed: 1.8ms preprocess, 45.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 58.6ms
# Speed: 1.6ms preprocess, 58.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.2ms
# Speed: 1.9ms preprocess, 42.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 52.2ms
# Speed: 1.7ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.5ms
# Speed: 1.9ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 55.7ms
# Speed: 3.9ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 54.0ms
# Speed: 1.6ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 43.8ms
# Speed: 1.9ms preprocess, 43.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 44.9ms
# Speed: 1.9ms preprocess, 44.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.0ms
# Speed: 1.6ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 50.3ms
# Speed: 1.8ms preprocess, 50.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.6ms
# Speed: 1.9ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 39.5ms
# Speed: 1.7ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 41.4ms
# Speed: 1.6ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 38.2ms
# Speed: 1.6ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 39.3ms
# Speed: 1.7ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 39.0ms
# Speed: 1.6ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 40.9ms
# Speed: 1.7ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 38.6ms
# Speed: 1.4ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 38.9ms
# Speed: 1.8ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 38.9ms
# Speed: 1.6ms preprocess, 38.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 38.2ms
# Speed: 1.7ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 40.6ms
# Speed: 1.6ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 50.0ms
# Speed: 1.8ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 42.6ms
# Speed: 1.6ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.0ms
# Speed: 1.8ms preprocess, 42.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 41.5ms
# Speed: 1.8ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 bench, 42.7ms
# Speed: 1.9ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 41.9ms
# Speed: 1.9ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 40.8ms
# Speed: 2.1ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.3ms
# Speed: 1.9ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 2 trucks, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.7ms
# Speed: 1.8ms preprocess, 40.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.7ms
# Speed: 1.9ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 51.1ms
# Speed: 1.8ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 2 trucks, 1 bench, 40.8ms
# Speed: 1.9ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 1 bench, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 1 bench, 66.0ms
# Speed: 1.6ms preprocess, 66.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 78.6ms
# Speed: 2.9ms preprocess, 78.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 40.9ms
# Speed: 1.7ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 1 bench, 42.6ms
# Speed: 1.6ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 2 trucks, 1 bench, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 1 bench, 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 1 bench, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 trucks, 1 bench, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 1 bench, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 1 bench, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 1 bench, 56.7ms
# Speed: 1.8ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 1 bench, 41.4ms
# Speed: 1.6ms preprocess, 41.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 1 bench, 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 1 bench, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bench, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 1 truck, 1 bench, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 41.9ms
# Speed: 1.7ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 42.0ms
# Speed: 1.7ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 40.7ms
# Speed: 1.8ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 53.4ms
# Speed: 1.7ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 1 bench, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 1 bench, 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 1 bench, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 1 bench, 39.8ms
# Speed: 1.6ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 1 bench, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 1 bench, 40.7ms
# Speed: 1.9ms preprocess, 40.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 1 bench, 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 truck, 1 bench, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 truck, 1 bench, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 truck, 1 bench, 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 truck, 1 bench, 39.9ms
# Speed: 1.7ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bench, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bench, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 38.3ms
# Speed: 1.6ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 1 bench, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 1 bench, 39.8ms
# Speed: 1.6ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bench, 38.3ms
# Speed: 1.8ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bench, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bench, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bench, 40.7ms
# Speed: 1.9ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bench, 39.1ms
# Speed: 1.7ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 38.4ms
# Speed: 1.8ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 17 cars, 1 truck, 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 truck, 42.1ms
# Speed: 1.8ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 43.2ms
# Speed: 1.8ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 42.7ms
# Speed: 1.8ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.5ms
# Speed: 1.8ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.2ms
# Speed: 1.9ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 2 trucks, 46.0ms
# Speed: 1.9ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 1 truck, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 42.2ms
# Speed: 1.8ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 40.0ms
# Speed: 1.9ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 43.6ms
# Speed: 1.8ms preprocess, 43.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 43.4ms
# Speed: 1.8ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 40.6ms
# Speed: 1.9ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 42.7ms
# Speed: 1.8ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 40.2ms
# Speed: 1.9ms preprocess, 40.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 39.3ms
# Speed: 1.8ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 truck, 40.2ms
# Speed: 1.8ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 40.0ms
# Speed: 1.8ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 51.3ms
# Speed: 1.8ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 47.5ms
# Speed: 1.7ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 39.2ms
# Speed: 1.5ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 40.2ms
# Speed: 1.8ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 45.8ms
# Speed: 1.9ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 41.5ms
# Speed: 1.8ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 41.8ms
# Speed: 1.8ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 57.4ms
# Speed: 1.9ms preprocess, 57.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 64.5ms
# Speed: 1.9ms preprocess, 64.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 57.3ms
# Speed: 1.8ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 55.5ms
# Speed: 1.8ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 55.8ms
# Speed: 1.7ms preprocess, 55.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 40.0ms
# Speed: 1.8ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 truck, 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 truck, 39.8ms
# Speed: 1.7ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 1 truck, 42.1ms
# Speed: 1.8ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 motorcycle, 1 truck, 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 motorcycle, 1 truck, 39.3ms
# Speed: 1.9ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 1 truck, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 1 truck, 41.2ms
# Speed: 1.9ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 motorcycle, 2 trucks, 42.4ms
# Speed: 2.1ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 41.5ms
# Speed: 1.8ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 40.7ms
# Speed: 1.8ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 41.2ms
# Speed: 1.9ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 44.1ms
# Speed: 1.9ms preprocess, 44.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 1 truck, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 1 truck, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 1 motorcycle, 1 truck, 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 1 motorcycle, 1 truck, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 1 motorcycle, 1 truck, 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 1 motorcycle, 1 truck, 41.5ms
# Speed: 1.7ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 motorcycle, 1 truck, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 1 motorcycle, 42.5ms
# Speed: 1.8ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 1 motorcycle, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 1 motorcycle, 47.2ms
# Speed: 1.8ms preprocess, 47.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 1 motorcycle, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 1 motorcycle, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 motorcycle, 40.6ms
# Speed: 1.7ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 42.0ms
# Speed: 1.7ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 39.7ms
# Speed: 1.7ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 47.9ms
# Speed: 1.7ms preprocess, 47.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 42.9ms
# Speed: 1.7ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 40.7ms
# Speed: 1.9ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 42.2ms
# Speed: 1.8ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 motorcycle, 43.7ms
# Speed: 1.8ms preprocess, 43.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 motorcycle, 1 truck, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 1 truck, 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 1 truck, 40.0ms
# Speed: 1.9ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 1 truck, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 motorcycle, 1 truck, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 motorcycle, 42.0ms
# Speed: 1.7ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 39.8ms
# Speed: 1.7ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 39.7ms
# Speed: 1.7ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 40.8ms
# Speed: 1.7ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 motorcycles, 1 truck, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 motorcycles, 1 truck, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 motorcycles, 1 truck, 46.2ms
# Speed: 1.7ms preprocess, 46.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 motorcycles, 1 truck, 39.3ms
# Speed: 1.7ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 39.2ms
# Speed: 1.8ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 1 motorcycle, 1 truck, 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 38.4ms
# Speed: 1.7ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 39.6ms
# Speed: 1.8ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 41.5ms
# Speed: 1.8ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 41.6ms
# Speed: 1.9ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 1 truck, 39.6ms
# Speed: 1.8ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 1 truck, 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 1 truck, 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 1 truck, 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 15 cars, 1 truck, 43.2ms
# Speed: 1.7ms preprocess, 43.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 1 truck, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.
